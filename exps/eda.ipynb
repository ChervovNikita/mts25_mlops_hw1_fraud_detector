# %%
import pandas as pd

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
train
# Out:
#         transaction_time                                 merch  \
# 0       2019-12-27 15:21                     fraud_Cormier LLC
# 1       2019-04-17 23:09       fraud_Brown, Homenick and Lesch
# 2       2019-09-23 15:02                  fraud_Ruecker-Mayert
# 3       2019-05-13 16:00     fraud_Mante, Luettgen and Hackett
# 4       2019-08-18 07:27                    fraud_Luettgen PLC
# ...                  ...                                   ...
# 786426  2019-04-10 12:35    fraud_O'Connell, Botsford and Hand
# 786427  2019-12-15 09:34      fraud_Adams, Kovacek and Kuhlman
# 786428  2019-10-12 10:22          fraud_Lind, Huel and McClure
# 786429  2019-10-18 09:01                      fraud_Rempel PLC
# 786430  2019-10-10 16:51  fraud_Medhurst, Cartwright and Ebert
#
#                 cat_id  amount       name_1    name_2 gender  \
# 0       health_fitness  148.04       Daniel  Martinez      M
# 1       health_fitness   39.40        Grace  Williams      F
# 2            kids_pets   52.96         Kyle      Park      M
# 3       health_fitness    7.66      Monique    Martin      F
# 4        gas_transport   51.59    Christine   Johnson      F
# ...                ...     ...          ...       ...    ...
# 786426            home   76.56         Ryan    Foster      M
# 786427     grocery_net   68.58          Jim   Johnson      M
# 786428   gas_transport   66.66  Christopher      Horn      M
# 786429     grocery_net   38.06       Samuel  Sandoval      M
# 786430   personal_care  148.36  Christopher   Johnson      M
#
#                                    street            one_city us_state  \
# 0                      8510 Acevedo Burgs                Kent       OR
# 1             28812 Charles Mill Apt. 628       Plantersville       AL
# 2            7507 Larry Passage Suite 859         Mount Perry       OH
# 3                   68276 Matthew Springs            Ratcliff       TX
# 4            8011 Chapman Tunnel Apt. 568  Blairsden-Graeagle       CA
# ...                                   ...                 ...      ...
# 786426       03921 Cole Mission Suite 882             Hampton       FL
# 786427            868 Brady Mill Apt. 837              Gretna       LA
# 786428                956 Sanchez Highway              Mallie       KY
# 786429                 0005 Morrison Land              Mounds       OK
# 786430  28711 Kristine Junction Suite 309          Greenville       OH
#
#         post_code      lat       lon  population_city  \
# 0           97033  45.0838 -120.6649               60
# 1           36758  32.6176  -86.9475             1412
# 2           43760  39.8788  -82.1880             1831
# 3           75858  31.3833  -95.0619               43
# 4           96103  39.8127 -120.6405             1725
# ...           ...      ...       ...              ...
# 786426      32044  29.8575  -82.1483             2060
# 786427      70056  29.8872  -90.0331            55581
# 786428      41836  37.2692  -82.9161              798
# 786429      74047  35.8896  -96.0887             7163
# 786430      45331  40.0987  -84.6342            22930
#
#                                                  jobs  merchant_lat  \
# 0                            Museum education officer     45.042827
# 1                                   Drilling engineer     31.872266
# 2                                   Barrister's clerk     40.010874
# 3                                Engineer, production     30.888406
# 4       Chartered legal executive (England and Wales)     39.376017
# ...                                               ...           ...
# 786426                                     Oncologist     29.235257
# 786427                           Biomedical scientist     29.015274
# 786428                             Facilities manager     37.515508
# 786429                         Fitness centre manager     35.203864
# 786430                                  Media planner     39.112400
#
#         merchant_lon  target
# 0        -120.709327       0
# 1         -87.828247       0
# 2         -81.841249       0
# 3         -95.141609       0
# 4        -121.311691       0
# ...              ...     ...
# 786426    -82.407844       0
# 786427    -90.564712       0
# 786428    -82.443788       0
# 786429    -96.999902       0
# 786430    -84.456052       0
#
# [786431 rows x 18 columns]

# %%
import catboost

# %%
import numpy as np
from datetime import datetime


def process_time(df):
    df = df.copy()
    
    df['transaction_time'] = pd.to_datetime(df['transaction_time'])
    
    df['hour'] = df['transaction_time'].dt.hour
    df['minute'] = df['transaction_time'].dt.minute
    df['time_of_day'] = (df['hour'] + df['minute'] / 60) / 24

    df['time_sin'] = np.sin(2 * np.pi * df['time_of_day'])
    df['time_cos'] = np.cos(2 * np.pi * df['time_of_day'])

    df['is_weekend'] = (df['transaction_time'].dt.dayofweek >= 5).astype(int)

    df = df.drop(columns=['hour', 'minute', 'time_of_day'])

    return df


def process_features(df):
    df = df.copy()
    df = process_time(df)

    df['amount_log'] = np.log(df['amount'] + 1)
    df['population_city_log'] = (df['population_city'] - df['population_city'].mean()) / df['population_city'].std()

    df['distance'] = np.sqrt((df['lat'] - df['merchant_lat']) ** 2 + (df['lon'] - df['merchant_lon']) ** 2)

    df.drop(columns=['name_1', 'name_2', 'population_city'], inplace=True)

    return df

# %%
from sklearn.model_selection import train_test_split

my_train, my_val = train_test_split(train, test_size=0.2, random_state=42)

train_y = my_train['target']
train_X = my_train.drop(columns=['target'])

val_y = my_val['target']
val_X = my_val.drop(columns=['target'])

# %%
processed_train = process_features(train_X)
processed_val = process_features(val_X)

# %%
cat_features = [
    'merch', 'cat_id', 'gender', 'street', 'one_city', 'us_state', 'post_code', 'jobs'
]
num_features = [
    'amount', 'lat', 'lon', 'merchant_lat', 'merchant_lon', 'distance', 'amount_log', 'population_city_log'
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(processed_train[num_features])
processed_train[num_features] = scaler.transform(processed_train[num_features])
processed_val[num_features] = scaler.transform(processed_val[num_features])

# %%
classifier = catboost.CatBoostClassifier(
    n_estimators=100,
    learning_rate=0.05,
    max_depth=5,
    random_state=42,
    class_weights=[1, 5]
)
classifier.fit(processed_train, train_y, cat_features=cat_features, verbose=50)
# Out:
# 0:	learn: 0.5692461	total: 94.4ms	remaining: 9.35s
# 50:	learn: 0.0359631	total: 4.25s	remaining: 4.09s
# 99:	learn: 0.0282843	total: 8.38s	remaining: 0us

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

def predict_and_evaluate(classifier, X, y, th):
    predicted = classifier.predict_proba(X)[:, 1]
    predicted = (predicted > th).astype(int)
    return predicted

predicted = predict_and_evaluate(classifier, processed_val, val_y, 0.5)

print('ROC AUC:', roc_auc_score(val_y, predicted))
print('Accuracy:', accuracy_score(val_y, predicted))
print('Precision:', precision_score(val_y, predicted))
print('Recall:', recall_score(val_y, predicted))
print('F1 Score:', f1_score(val_y, predicted))
# Out:
# ROC AUC: 0.8853072948778975
# Accuracy: 0.997030905287786
# Precision: 0.7297297297297297
# Recall: 0.7722772277227723
# F1 Score: 0.7504008551576697

# %%
processed_test = process_features(test)

# %%
predicted_test = classifier.predict(processed_test)

# %%
result = pd.DataFrame({'index': np.arange(len(predicted_test)), 'prediction': predicted_test})
result.to_csv('../data/result.csv', index=False)

# %%
pd.read_csv('../data/result.csv')
# Out:
#          index  prediction
# 0            0           0
# 1            1           0
# 2            2           0
# 3            3           1
# 4            4           1
# ...        ...         ...
# 262139  262139           1
# 262140  262140           0
# 262141  262141           0
# 262142  262142           1
# 262143  262143           0
#
# [262144 rows x 2 columns]

# %%
classifier.save_model('../models/catboost_model.cbm')

# %%
import joblib
joblib.dump(scaler, '../models/scaler.pkl')
# Out:
# ['../models/scaler.pkl']
